# %% [markdown]
# 3 GPU 28 CPU Execution of ResNet 50 model with AMP (Automatic Mixed Precision)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, DistributedSampler
from torchvision import datasets, models
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time
import matplotlib.pyplot as plt
import multiprocessing as mp
import torch.distributed as dist
import torch.cuda.amp as amp  # import for automatic mixed precision
from torchvision.models import resnet50, ResNet50_Weights

# %%
world_size = torch.cuda.device_count()
world_size
# Out:
# 4

# %%
data_dir = '/home/patel.devki1/Dataset/lung_colon_image_set/'  # Updated with our dataset directory
output_dir = '/home/patel.devki1/Dataset'  # Updated with our desired output directory

# %%
def setup(rank, world_size):
    os.environ['MASTER_ADDR'] = 'localhost'
    os.environ['MASTER_PORT'] = '13285'
    dist.init_process_group("nccl", rank=rank, world_size=world_size)
    torch.cuda.set_device(rank)
    print(f"[Rank {rank}] Initialization complete. Using world size {world_size}.")

def cleanup():
    dist.destroy_process_group()

class LungColonCancerDataset(datasets.ImageFolder):
    def __init__(self, root_dir, transform=None):
        super(LungColonCancerDataset, self).__init__(root=root_dir, transform=transform)

def evaluate(model, dataloader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.cuda()
            labels = labels.cuda()
            
            # Use AMP for evaluation
            with amp.autocast():
                outputs = model(inputs)
            
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    return accuracy, precision, recall, f1


def plot_learning_curves(train_losses, valid_losses, valid_accuracies):
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

    plt.plot(valid_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Validation Accuracy')
    plt.show()

# %%
def train(rank, world_size, batch_size, num_workers):
    setup(rank, world_size)

    print(f"[Rank {rank}] Starting training...")

    transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    train_dataset = LungColonCancerDataset(root_dir=os.path.join(data_dir, 'train'), transform=transform)
    train_sampler = DistributedSampler(train_dataset, num_replicas=world_size, rank=rank)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)

    validation_dataset = LungColonCancerDataset(root_dir=os.path.join(data_dir, 'valid'), transform=transform)
    validation_sampler = DistributedSampler(validation_dataset, num_replicas=world_size, rank=rank)
    validation_loader = DataLoader(validation_dataset, batch_size=batch_size, sampler=validation_sampler, num_workers=num_workers)
    
    weights=ResNet50_Weights.DEFAULT
    model = models.resnet50(weights=weights)
    num_ftrs = model.fc.in_features
    num_classes = 5
    model.fc = nn.Linear(num_ftrs, num_classes)
    model = model.cuda(rank)
    ddp_model = nn.parallel.DistributedDataParallel(model, device_ids=[rank])
    scaler = amp.GradScaler()

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(ddp_model.parameters(), lr=0.001, momentum=0.9)

    train_losses = []
    valid_losses = []
    valid_accuracies = []

    start_time = time.time()

    for epoch in range(10):  # Adjust the number of epochs
        epoch_start_time = time.time()  # Start time for the epoch
        ddp_model.train()
        epoch_train_losses = []

        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.cuda(rank)
            labels = labels.cuda(rank)

            optimizer.zero_grad()

            # Using AMP for automatic mixed precision
            with amp.autocast():
                outputs = ddp_model(inputs)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            epoch_train_losses.append(loss.item())

            if batch_idx % 10 == 0:  # Log every 10 batches
                print(f"[Rank {rank}] Epoch {epoch+1} Batch {batch_idx+1}: Loss {loss.item()}")

        train_losses.append(sum(epoch_train_losses) / len(epoch_train_losses))

        epoch_duration = time.time() - epoch_start_time
        print(f"Each Epoch Duration {epoch_duration}")

        valid_loss, valid_accuracy, _, _ = evaluate(model, validation_loader)
        valid_losses.append(valid_loss)
        valid_accuracies.append(valid_accuracy)

    plot_learning_curves(train_losses, valid_losses, valid_accuracies)

    print("Test Results:")
    test_dataset = LungColonCancerDataset(root_dir=os.path.join(data_dir, 'test'), transform=transform)
    test_sampler = DistributedSampler(test_dataset, num_replicas=world_size, rank=rank)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler=test_sampler, num_workers=num_workers)
    test_accuracy, test_precision, test_recall, test_f1 = evaluate(model, test_loader)

    cleanup()
    end_time = time.time()
    print("total end_time", end_time)

    duration = end_time - start_time
    print(f"Rank {rank}: Training duration: {duration:.2f} seconds")

    torch.save(model.state_dict(), f'lung_colon_cancer_model_rank{rank}.pth')
    return model

# %%
if __name__ == '__main__':
    world_size = 3
    # using bigger batch size to see the difference in AMP
    batch_size = 500 
    num_workers = 28
    processes = []
    for rank in range(world_size):
        p = mp.Process(target=train, args=(rank, world_size, batch_size, num_workers))
        p.start() 
        processes.append(p)
    for p in processes:
        p.join()
# Out:
# [Rank 0] Initialization complete. Using world size 3.
# [Rank 0] Starting training...
# [Rank 1] Initialization complete. Using world size 3.
# [Rank 1] Starting training...
# [Rank 2] Initialization complete. Using world size 3.
# [Rank 2] Starting training...
# [Rank 2] Epoch 1 Batch 1: Loss 1.584625005722046
# [Rank 1] Epoch 1 Batch 1: Loss 1.5815175771713257
# [Rank 0] Epoch 1 Batch 1: Loss 1.5844765901565552
# [Rank 2] Epoch 1 Batch 11: Loss 1.488019585609436[Rank 1] Epoch 1 Batch 11: Loss 1.4536855220794678
#
# [Rank 0] Epoch 1 Batch 11: Loss 1.4728769063949585
# Each Epoch Duration 15.776768922805786
# Each Epoch Duration 15.784164905548096
# Each Epoch Duration 15.790407419204712
# Accuracy: 0.5360
# Precision: 0.5384
# Recall: 0.5286
# F1 Score: 0.4761
# Accuracy: 0.4988
# Precision: 0.5275
# Recall: 0.5156
# F1 Score: 0.4422
# Accuracy: 0.5252
# Precision: 0.4875
# Recall: 0.5166
# F1 Score: 0.4528
# [Rank 1] Epoch 2 Batch 1: Loss 1.3796591758728027[Rank 2] Epoch 2 Batch 1: Loss 1.3786709308624268[Rank 0] Epoch 2 Batch 1: Loss 1.3852324485778809
#
#
# [Rank 1] Epoch 2 Batch 11: Loss 1.1482290029525757[Rank 0] Epoch 2 Batch 11: Loss 1.1770620346069336
#
# [Rank 2] Epoch 2 Batch 11: Loss 1.1942949295043945
# Each Epoch Duration 14.665266990661621
# Each Epoch Duration 14.880940914154053
# Each Epoch Duration 14.244891166687012
# Accuracy: 0.7854
# Precision: 0.7864
# Recall: 0.7920
# F1 Score: 0.7824
# Accuracy: 0.7950
# Precision: 0.8001
# Recall: 0.7908
# F1 Score: 0.7849
# Accuracy: 0.8201
# Precision: 0.8213
# Recall: 0.8171
# F1 Score: 0.8128
# [Rank 0] Epoch 3 Batch 1: Loss 1.0808783769607544[Rank 1] Epoch 3 Batch 1: Loss 1.0711718797683716
# [Rank 2] Epoch 3 Batch 1: Loss 1.0682402849197388
#
# [Rank 1] Epoch 3 Batch 11: Loss 0.8409072160720825[Rank 2] Epoch 3 Batch 11: Loss 0.9047580361366272[Rank 0] Epoch 3 Batch 11: Loss 0.8673776984214783
#
#
# Each Epoch Duration 14.764674425125122
# Each Epoch Duration 13.893878936767578
# Each Epoch Duration 14.613693952560425
# Accuracy: 0.8705
# Precision: 0.8710
# Recall: 0.8743
# F1 Score: 0.8720
# Accuracy: 0.8777
# Precision: 0.8756
# Recall: 0.8756
# F1 Score: 0.8745
# Accuracy: 0.8897
# Precision: 0.8865
# Recall: 0.8870
# F1 Score: 0.8862
# [Rank 0] Epoch 4 Batch 1: Loss 0.7834632396697998[Rank 2] Epoch 4 Batch 1: Loss 0.7771692872047424
#
# [Rank 1] Epoch 4 Batch 1: Loss 0.7759925723075867
# [Rank 1] Epoch 4 Batch 11: Loss 0.5839101076126099[Rank 2] Epoch 4 Batch 11: Loss 0.6599246263504028[Rank 0] Epoch 4 Batch 11: Loss 0.6084821820259094
#
#
# Each Epoch Duration 14.835176706314087
# Each Epoch Duration 14.544727802276611Each Epoch Duration 14.961269855499268
#
# Accuracy: 0.9065
# Precision: 0.9101
# Recall: 0.9086
# F1 Score: 0.9086
# Accuracy: 0.9089
# Precision: 0.9070
# Recall: 0.9079
# F1 Score: 0.9073
# Accuracy: 0.9101
# Precision: 0.9074
# Recall: 0.9077
# F1 Score: 0.9075
# [Rank 2] Epoch 5 Batch 1: Loss 0.5518021583557129[Rank 1] Epoch 5 Batch 1: Loss 0.5413450002670288[Rank 0] Epoch 5 Batch 1: Loss 0.5501118302345276
#
#
# [Rank 2] Epoch 5 Batch 11: Loss 0.4840083718299866[Rank 1] Epoch 5 Batch 11: Loss 0.4078063666820526
#
# [Rank 0] Epoch 5 Batch 11: Loss 0.43302121758461
# Each Epoch Duration 14.458226203918457
# Each Epoch Duration 14.562996625900269
# Each Epoch Duration 14.67836308479309
# Accuracy: 0.9245
# Precision: 0.9229
# Recall: 0.9237
# F1 Score: 0.9232
# Accuracy: 0.9293
# Precision: 0.9276
# Recall: 0.9275
# F1 Score: 0.9276
# Accuracy: 0.9221
# Precision: 0.9254
# Recall: 0.9236
# F1 Score: 0.9239
# [Rank 2] Epoch 6 Batch 1: Loss 0.401457816362381
# [Rank 1] Epoch 6 Batch 1: Loss 0.38674089312553406[Rank 0] Epoch 6 Batch 1: Loss 0.39751705527305603
#
# [Rank 0] Epoch 6 Batch 11: Loss 0.3216627240180969[Rank 2] Epoch 6 Batch 11: Loss 0.36770811676979065
#
# [Rank 1] Epoch 6 Batch 11: Loss 0.2990010380744934
# Each Epoch Duration 14.735076189041138
# Each Epoch Duration 14.525542497634888
# Each Epoch Duration 14.469368696212769
# Accuracy: 0.9353
# Precision: 0.9339
# Recall: 0.9337
# F1 Score: 0.9337
# Accuracy: 0.9400
# Precision: 0.9389
# Recall: 0.9393
# F1 Score: 0.9391
# Accuracy: 0.9329
# Precision: 0.9354
# Recall: 0.9340
# F1 Score: 0.9343
# [Rank 2] Epoch 7 Batch 1: Loss 0.3077508509159088
# [Rank 0] Epoch 7 Batch 1: Loss 0.30416494607925415
# [Rank 1] Epoch 7 Batch 1: Loss 0.29166507720947266
# [Rank 2] Epoch 7 Batch 11: Loss 0.29085275530815125[Rank 1] Epoch 7 Batch 11: Loss 0.23146507143974304[Rank 0] Epoch 7 Batch 11: Loss 0.2515343725681305
#
#
# Each Epoch Duration 14.397775411605835
# Each Epoch Duration 14.477705240249634
# Each Epoch Duration 14.853696823120117
# Accuracy: 0.9472
# Precision: 0.9498
# Recall: 0.9481
# F1 Score: 0.9485
# Accuracy: 0.9388
# Precision: 0.9377
# Recall: 0.9375
# F1 Score: 0.9375
# Accuracy: 0.9448
# Precision: 0.9440
# Recall: 0.9443
# F1 Score: 0.9441
# [Rank 1] Epoch 8 Batch 1: Loss 0.23253558576107025[Rank 2] Epoch 8 Batch 1: Loss 0.2476806640625[Rank 0] Epoch 8 Batch 1: Loss 0.24496647715568542
#
#
# [Rank 1] Epoch 8 Batch 11: Loss 0.18739792704582214
# [Rank 0] Epoch 8 Batch 11: Loss 0.20488561689853668
# [Rank 2] Epoch 8 Batch 11: Loss 0.2372387796640396
# Each Epoch Duration 14.254251480102539
# Each Epoch Duration 14.557415008544922
# Each Epoch Duration 14.395563125610352
# Accuracy: 0.9556
# Precision: 0.9576
# Recall: 0.9565
# F1 Score: 0.9569
# Accuracy: 0.9496
# Precision: 0.9489
# Recall: 0.9492
# F1 Score: 0.9490
# Accuracy: 0.9412
# Precision: 0.9399
# Recall: 0.9398
# F1 Score: 0.9398
# [Rank 0] Epoch 9 Batch 1: Loss 0.20463067293167114[Rank 1] Epoch 9 Batch 1: Loss 0.1931702196598053
#
# [Rank 2] Epoch 9 Batch 1: Loss 0.20653212070465088
# [Rank 2] Epoch 9 Batch 11: Loss 0.19846899807453156[Rank 0] Epoch 9 Batch 11: Loss 0.1723719835281372[Rank 1] Epoch 9 Batch 11: Loss 0.15653611719608307
#
#
# Each Epoch Duration 14.090921401977539Each Epoch Duration 14.304460287094116
#
# Each Epoch Duration 14.547919034957886
# Accuracy: 0.9580
# Precision: 0.9600
# Recall: 0.9589
# F1 Score: 0.9592
# Accuracy: 0.9448
# Precision: 0.9437
# Recall: 0.9434
# F1 Score: 0.9434
# Accuracy: 0.9532
# Precision: 0.9526
# Recall: 0.9528
# F1 Score: 0.9527
# [Rank 1] Epoch 10 Batch 1: Loss 0.16551074385643005[Rank 2] Epoch 10 Batch 1: Loss 0.17740526795387268[Rank 0] Epoch 10 Batch 1: Loss 0.17540204524993896
#
#
# [Rank 2] Epoch 10 Batch 11: Loss 0.16973130404949188[Rank 0] Epoch 10 Batch 11: Loss 0.14830300211906433[Rank 1] Epoch 10 Batch 11: Loss 0.13323816657066345
#
#
# Each Epoch Duration 14.650674104690552
# Each Epoch Duration 15.185574531555176
# Each Epoch Duration 14.386192321777344
# Accuracy: 0.9508
# Precision: 0.9499
# Recall: 0.9495
# F1 Score: 0.9495
# Accuracy: 0.9604
# Precision: 0.9618
# Recall: 0.9615
# F1 Score: 0.9616
# Test Results:
# Test Results:
# Accuracy: 0.9568
# Precision: 0.9563
# Recall: 0.9564
# F1 Score: 0.9563
# Test Results:
# Accuracy: 0.9568
# Precision: 0.9560
# Recall: 0.9557
# F1 Score: 0.9557
# total end_time 1713139657.1492982
# Rank 2: Training duration: 222.88 seconds
# Accuracy: 0.9484
# Precision: 0.9509
# Recall: 0.9501
# F1 Score: 0.9505
# total end_time 1713139657.3702998
# Rank 1: Training duration: 223.10 seconds
# Accuracy: 0.9556
# Precision: 0.9560
# Recall: 0.9556
# F1 Score: 0.9555
# total end_time 1713139657.7058904
# Rank 0: Training duration: 223.43 seconds

# %% [markdown]
# Inference: update
#
# Average execution time per Epoch
#
# Epoch 1: 15.776768922805786
#
# Epoch 2: 14.764674425125122
#
# Epoch 3: 14.613693952560425
#
# Epoch 4: 14.961269855499268
#
# Epoch 5: 14.67836308479309
#
# Epoch 6: 14.735076189041138
#
# Epoch 7: 14.853696823120117
#
# Epoch 8: 14.395563125610352
#
# Epoch 9: 14.547919034957886
#
# Epoch 10: 15.185574531555176
#
#
# So, the average execution time per Epoch is approximately 14.91 seconds.
