# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, DistributedSampler
import torch.distributed as dist
import torch.multiprocessing as mp
from torchvision.models import resnet50, ResNet50_Weights
import time
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
world_size = torch.cuda.device_count()
world_size
# Out:
# 4

# %%
# !pwd
# Out:
# /home/patel.devki1/Dataset

# %%
data_dir = '/home/patel.devki1/Dataset/lung_colon_image_set/'

# %%
def setup(rank, world_size):
    os.environ['MASTER_ADDR'] = 'localhost'
    os.environ['MASTER_PORT'] = '13285'
    dist.init_process_group("nccl", rank=rank, world_size=world_size)
    torch.cuda.set_device(rank)
    print(f"[Rank {rank}] Initialization complete. Using world size {world_size}.")

def cleanup():
    dist.destroy_process_group()

class LungColonCancerDataset(datasets.ImageFolder):
    def __init__(self, root_dir, transform=None):
        super(LungColonCancerDataset, self).__init__(root=root_dir, transform=transform)
        
def evaluate(model, dataloader):
    model.eval()  # Set the model to evaluation mode
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.cuda()  # Assuming you're using GPU
            labels = labels.cuda()  # Assuming you're using GPU
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    return accuracy, precision, recall, f1

def plot_learning_curves(train_losses, valid_losses, valid_accuracies):
    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

    plt.plot(valid_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Validation Accuracy')
    plt.show()

def train(rank, world_size):
    setup(rank, world_size)
    
    print(f"[Rank {rank}] Starting training...")

    transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    # training dataset
    train_dataset = LungColonCancerDataset(root_dir=os.path.join(data_dir, 'train'), transform=transform)
    train_sampler = DistributedSampler(train_dataset, num_replicas=world_size, rank=rank)
    train_loader = DataLoader(train_dataset, batch_size=1000, sampler=train_sampler, num_workers=8)  # num_workers
    
    # validation dataset
    validation_dataset = LungColonCancerDataset(root_dir=os.path.join(data_dir, 'valid'), transform=transform)
    validation_sampler = DistributedSampler(validation_dataset, num_replicas=world_size, rank=rank)
    validation_loader = DataLoader(validation_dataset, batch_size=1000, sampler=validation_sampler, num_workers=8)  # num_workers
    
    # test dataset
    test_dataset = LungColonCancerDataset(root_dir=os.path.join(data_dir, 'test'), transform=transform)
    test_sampler = DistributedSampler(test_dataset, num_replicas=world_size, rank=rank)
    test_loader = DataLoader(test_dataset, batch_size=1000, sampler=test_sampler, num_workers=8)  # num_workers
    
    print(f"[Rank {rank}] Loaded {len(train_dataset)} images for training.")

    # model = models.resnet50(pretrained=True)
    weights = ResNet50_Weights.DEFAULT
    model = resnet50(weights=weights)
    num_ftrs = model.fc.in_features
    num_classes = 5
    model.fc = nn.Linear(num_ftrs, num_classes)  # 5 classes
    model = model.cuda(rank)
    ddp_model = nn.parallel.DistributedDataParallel(model, device_ids=[rank])
    
    print(f"[Rank {rank}] Model initialized and wrapped in DDP.")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(ddp_model.parameters(), lr=0.001, momentum=0.9)
    
    print(f"[Rank {rank}] Optimizer and loss function are set up.")

    train_losses = []
    valid_losses = []
    valid_accuracies = []

    start_time = time.time()  # Start timing
    print("start_time", start_time)
    
    for epoch in range(10):  # Adjust the number of epochs
        epoch_start_time = time.time()  # Start time for the epoch
        ddp_model.train()
        epoch_train_losses = []
        for batch_idx, (inputs, labels) in enumerate(train_loader):
            inputs = inputs.cuda(rank)
            labels = labels.cuda(rank)

            optimizer.zero_grad()
            outputs = ddp_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_train_losses.append(loss.item())

            if batch_idx % 10 == 0:  # Log every 10 batches
                print(f"[Rank {rank}] Epoch {epoch+1} Batch {batch_idx+1}: Loss {loss.item()}")

        train_losses.append(sum(epoch_train_losses) / len(epoch_train_losses))

        epoch_duration = time.time() - epoch_start_time  # Calculate duration of the epoch
        print(f"Each Epoch Duration {epoch_duration}")
        
        # Validation
        print("Validation Results:")
        valid_loss, valid_accuracy, _, _ = evaluate(model, validation_loader)
        valid_losses.append(valid_loss)
        valid_accuracies.append(valid_accuracy)

    plot_learning_curves(train_losses, valid_losses, valid_accuracies)

    print("Test Results:")
    test_accuracy, test_precision, test_recall, test_f1 = evaluate(model, test_loader)

    cleanup()
    
    end_time = time.time()  # End timing
    print("total end_time", end_time)
    
    duration = end_time - start_time
    print(f"Rank {rank}: Training duration: {duration:.2f} seconds")
    
    # saving the model for later use without disturbing the rest of the code
    torch.save(model.state_dict(), 'lung_colon_cancer_model.pth')
    
    # return the model to use for other evaluations
    return model

# %%
if __name__ == '__main__':
    world_size = torch.cuda.device_count()
    processes = []
    for rank in range(world_size):
        p = mp.Process(target=train, args=(rank, world_size))
        p.start() 
        processes.append(p)
    for p in processes:
        p.join()
# Out:
# [Rank 0] Initialization complete. Using world size 4.
# [Rank 0] Starting training...
# [Rank 0] Loaded 20000 images for training.
# [Rank 2] Initialization complete. Using world size 4.
# [Rank 2] Starting training...
# [Rank 1] Initialization complete. Using world size 4.
# [Rank 1] Starting training...
# [Rank 3] Initialization complete. Using world size 4.
# [Rank 3] Starting training...
# [Rank 2] Loaded 20000 images for training.
# [Rank 1] Loaded 20000 images for training.
# [Rank 3] Loaded 20000 images for training.
# [Rank 2] Model initialized and wrapped in DDP.
# [Rank 1] Model initialized and wrapped in DDP.[Rank 0] Model initialized and wrapped in DDP.
#
# [Rank 2] Optimizer and loss function are set up.
# start_time 1713125332.4144173
# [Rank 3] Model initialized and wrapped in DDP.
# [Rank 0] Optimizer and loss function are set up.
# [Rank 1] Optimizer and loss function are set up.start_time
# 1713125332.419515start_time
# [Rank 3] Optimizer and loss function are set up.
# 1713125332.4210856start_time
#  1713125332.4232914
# [Rank 3] Epoch 1 Batch 1: Loss 1.5794765949249268[Rank 1] Epoch 1 Batch 1: Loss 1.5946192741394043[Rank 0] Epoch 1 Batch 1: Loss 1.5858724117279053
#
#
# [Rank 2] Epoch 1 Batch 1: Loss 1.591816782951355
# Each Epoch Duration 18.603377103805542
# Validation Results:
# Each Epoch Duration 18.615432024002075
# Validation Results:
# Each Epoch Duration 18.61538577079773
# Each Epoch Duration 18.61785626411438Validation Results:
#
# Validation Results:
# Accuracy: 0.1648
# Precision: 0.1358
# Recall: 0.1743
# F1 Score: 0.1468
# Accuracy: 0.2016
# Precision: 0.1603
# Recall: 0.1958
# F1 Score: 0.1715
# Accuracy: 0.1888
# Precision: 0.1575
# Recall: 0.1876
# F1 Score: 0.1633
# Accuracy: 0.1920
# Precision: 0.1458
# Recall: 0.1881
# F1 Score: 0.1580
# [Rank 3] Epoch 2 Batch 1: Loss 1.5393848419189453[Rank 2] Epoch 2 Batch 1: Loss 1.5520610809326172
# [Rank 1] Epoch 2 Batch 1: Loss 1.5571470260620117
#
# [Rank 0] Epoch 2 Batch 1: Loss 1.5489305257797241
# Each Epoch Duration 17.65189838409424
# Validation Results:
# Each Epoch Duration 17.519160270690918
# Validation Results:
# Each Epoch Duration 17.683000326156616
# Validation Results:
# Each Epoch Duration 17.671993494033813
# Validation Results:
# Accuracy: 0.2656
# Precision: 0.2558
# Recall: 0.2649
# F1 Score: 0.2565
# Accuracy: 0.2672
# Precision: 0.2551
# Recall: 0.2646
# F1 Score: 0.2568
# Accuracy: 0.2432
# Precision: 0.2341
# Recall: 0.2495
# F1 Score: 0.2393
# Accuracy: 0.2784
# Precision: 0.2743
# Recall: 0.2745
# F1 Score: 0.2686
# [Rank 1] Epoch 3 Batch 1: Loss 1.47921884059906[Rank 3] Epoch 3 Batch 1: Loss 1.4570825099945068[Rank 0] Epoch 3 Batch 1: Loss 1.4723200798034668
#
# [Rank 2] Epoch 3 Batch 1: Loss 1.4702595472335815
#
# Each Epoch Duration 17.626681804656982
# Each Epoch Duration 17.20659375190735Validation Results:
#
# Validation Results:Each Epoch Duration 17.647578716278076
# Each Epoch Duration 17.428343772888184
#
# Validation Results:Validation Results:
#
# Accuracy: 0.5264
# Precision: 0.5084
# Recall: 0.5292
# F1 Score: 0.5154
# Accuracy: 0.5024
# Precision: 0.4907
# Recall: 0.5000
# F1 Score: 0.4916
# Accuracy: 0.5088
# Precision: 0.4951
# Recall: 0.5142
# F1 Score: 0.4984
# Accuracy: 0.5312
# Precision: 0.5075
# Recall: 0.5266
# F1 Score: 0.5133
# [Rank 0] Epoch 4 Batch 1: Loss 1.3750483989715576
# [Rank 3] Epoch 4 Batch 1: Loss 1.3544212579727173[Rank 1] Epoch 4 Batch 1: Loss 1.3798160552978516[Rank 2] Epoch 4 Batch 1: Loss 1.367545485496521
#
#
# Each Epoch Duration 17.36798095703125
# Validation Results:
# Each Epoch Duration 17.629002571105957
# Validation Results:
# Each Epoch Duration 17.581775426864624
# Validation Results:
# Each Epoch Duration 17.39395523071289
# Validation Results:
# Accuracy: 0.7024
# Precision: 0.6941
# Recall: 0.7069
# F1 Score: 0.6954
# Accuracy: 0.6896
# Precision: 0.6793
# Recall: 0.6904
# Accuracy: 0.7072
# F1 Score: 0.6816Precision: 0.7039
#
# Recall: 0.7052
# F1 Score: 0.6991
# Accuracy: 0.7168
# Precision: 0.7048
# Recall: 0.7146
# F1 Score: 0.7036
# [Rank 1] Epoch 5 Batch 1: Loss 1.2682106494903564[Rank 2] Epoch 5 Batch 1: Loss 1.2545220851898193
# [Rank 3] Epoch 5 Batch 1: Loss 1.2417079210281372
#
# [Rank 0] Epoch 5 Batch 1: Loss 1.2661702632904053
# Each Epoch Duration 17.335701942443848Each Epoch Duration 17.472678184509277
#
# Validation Results:Validation Results:
#
# Each Epoch Duration 17.314054250717163
# Each Epoch Duration 17.339325189590454Validation Results:
#
# Validation Results:
# Accuracy: 0.7744
# Precision: 0.7681
# Recall: 0.7726
# F1 Score: 0.7665
# Accuracy: 0.8144
# Precision: 0.8095
# Recall: 0.8120
# F1 Score: 0.8086
# Accuracy: 0.7936Accuracy: 0.7888
# Precision: 0.7858
#
# Precision: 0.7925
# Recall: 0.7938Recall: 0.7926
#
# F1 Score: 0.7878
# F1 Score: 0.7857
# [Rank 1] Epoch 6 Batch 1: Loss 1.1481651067733765[Rank 2] Epoch 6 Batch 1: Loss 1.1367332935333252[Rank 3] Epoch 6 Batch 1: Loss 1.1247438192367554[Rank 0] Epoch 6 Batch 1: Loss 1.1500952243804932
#
#
#
# Each Epoch Duration 17.084208011627197
# Each Epoch Duration 17.07072925567627Validation Results:
#
# Validation Results:
# Each Epoch Duration 17.432342529296875
# Validation Results:
# Each Epoch Duration 17.28516387939453
# Validation Results:
# Accuracy: 0.8352
# Precision: 0.8353
# Recall: 0.8348
# F1 Score: 0.8317
# Accuracy: 0.8208
# Precision: 0.8199
# Recall: 0.8241
# F1 Score: 0.8194
# Accuracy: 0.8688
# Precision: 0.8686
# Recall: 0.8666
# F1 Score: 0.8655
# Accuracy: 0.8272
# Precision: 0.8298
# Recall: 0.8251
# F1 Score: 0.8220
# [Rank 1] Epoch 7 Batch 1: Loss 1.0244842767715454[Rank 3] Epoch 7 Batch 1: Loss 1.0073575973510742[Rank 0] Epoch 7 Batch 1: Loss 1.0312546491622925
#
#
# [Rank 2] Epoch 7 Batch 1: Loss 1.017738699913025
# Each Epoch Duration 17.870243310928345
# Validation Results:
# Each Epoch Duration 17.522297859191895
# Validation Results:
# Each Epoch Duration 17.82447862625122
# Validation Results:
# Each Epoch Duration 17.601037979125977
# Validation Results:
# Accuracy: 0.8576
# Precision: 0.8596
# Recall: 0.8578
# F1 Score: 0.8553
# Accuracy: 0.8944
# Precision: 0.8961
# Recall: 0.8923
# F1 Score: 0.8921
# Accuracy: 0.8544
# Precision: 0.8546
# Recall: 0.8541
# F1 Score: 0.8518
# Accuracy: 0.8384
# Precision: 0.8391
# Recall: 0.8414
# F1 Score: 0.8384
# [Rank 3] Epoch 8 Batch 1: Loss 0.8933295011520386
# [Rank 1] Epoch 8 Batch 1: Loss 0.9050504565238953[Rank 2] Epoch 8 Batch 1: Loss 0.9017876386642456[Rank 0] Epoch 8 Batch 1: Loss 0.9143127202987671
#
#
# Each Epoch Duration 17.697247982025146
# Validation Results:
# Each Epoch Duration 18.210209846496582
# Validation Results:Each Epoch Duration 17.905840158462524
#
# Each Epoch Duration 17.921806573867798Validation Results:
#
# Validation Results:
# Accuracy: 0.8656
# Precision: 0.8684
# Recall: 0.8656
# F1 Score: 0.8637
# Accuracy: 0.9152
# Precision: 0.9186
# Recall: 0.9132
# F1 Score: 0.9137
# Accuracy: 0.8608
# Precision: 0.8622
# Recall: 0.8635
# F1 Score: 0.8610
# Accuracy: 0.8640
# Precision: 0.8627
# Recall: 0.8634
# F1 Score: 0.8614
# [Rank 3] Epoch 9 Batch 1: Loss 0.7869623899459839[Rank 1] Epoch 9 Batch 1: Loss 0.795261025428772[Rank 2] Epoch 9 Batch 1: Loss 0.793331503868103
#
#
# [Rank 0] Epoch 9 Batch 1: Loss 0.8044533133506775
# Each Epoch Duration 17.381189823150635
# Validation Results:
# Each Epoch Duration 17.18100094795227
# Each Epoch Duration 17.657681703567505Validation Results:
#
# Validation Results:Each Epoch Duration 17.683056116104126
#
# Validation Results:
# Accuracy: 0.9200
# Precision: 0.9231
# Recall: 0.9183
# F1 Score: 0.9187
# Accuracy: 0.8784Accuracy: 0.8800
#
# Precision: 0.8764Precision: 0.8818
#
# Recall: 0.8774Recall: 0.8823
#
# F1 Score: 0.8759F1 Score: 0.8805
#
# Accuracy: 0.8800
# Precision: 0.8813
# Recall: 0.8809
# F1 Score: 0.8790
# [Rank 0] Epoch 10 Batch 1: Loss 0.7056163549423218[Rank 3] Epoch 10 Batch 1: Loss 0.6906909346580505
#
# [Rank 1] Epoch 10 Batch 1: Loss 0.6962951421737671[Rank 2] Epoch 10 Batch 1: Loss 0.6947370171546936
#
# Each Epoch Duration 18.261967420578003
# Validation Results:
# Each Epoch Duration 18.191513299942017
# Validation Results:
# Each Epoch Duration 18.474428415298462
# Each Epoch Duration 18.295212507247925Validation Results:
#
# Validation Results:
# Accuracy: 0.8896
# Precision: 0.8905
# Recall: 0.8915
# F1 Score: 0.8903
# Accuracy: 0.8928
# Precision: 0.8930
# Recall: 0.8946
# F1 Score: 0.8927
# Accuracy: 0.8928
# Precision: 0.8906
# Recall: 0.8915
# F1 Score: 0.8907
# Test Results:
# Test Results:
# Accuracy: 0.9248
# Precision: 0.9269
# Recall: 0.9232
# F1 Score: 0.9236
# Test Results:
# Test Results:
# Accuracy: 0.9168
# Precision: 0.9177
# Recall: 0.9181
# F1 Score: 0.9177
# total end_time 1713125588.3368506
# Rank 1: Training duration: 255.92 seconds
# Accuracy: 0.8960
# Precision: 0.8983
# Recall: 0.8965
# F1 Score: 0.8966
# total end_time 1713125588.3975081
# Rank 0: Training duration: 255.98 seconds
# Accuracy: 0.8976
# Precision: 0.8959
# Recall: 0.8964
# F1 Score: 0.8952
# total end_time 1713125588.7602212
# Rank 2: Training duration: 256.35 seconds
# Accuracy: 0.9088
# Precision: 0.9101
# Recall: 0.9078
# F1 Score: 0.9085
# total end_time 1713125588.9523878
# Rank 3: Training duration: 256.53 seconds

# %% [markdown]
# Conclusion:
#
# Epoch 1:  18.61301279067993 seconds
#
# Epoch 2:  17.631513118993895 seconds
#
# Epoch 3:  17.477299261432647 seconds
#
# Epoch 4:  17.74317854642868 seconds
#
# Epoch 5:  17.365439891815185 seconds
#
# Epoch 6:  17.218110919248717 seconds
#
# Epoch 7:  17.70451444387436 seconds
#
# Epoch 8:  17.933776140213014 seconds
#
# Epoch 9:  17.475732147693634 seconds
#
# Epoch 10: 18.3057804107666 seconds
#
# Average duration for each epoch ≈ 17.78 seconds
